# %%
fname = "Arvind"
lname = "reddy"

fullname = fname+ " " +lname
print(f" your name : {fullname}")
# Out:
#  your name : Arvind reddy

# %%
r=10
fname=" Arvind "
print(f"Your name is repeated :{r}\n {fname*r}")
# Out:
# Your name is repeated :10
#   Arvind  Arvind  Arvind  Arvind  Arvind  Arvind  Arvind  Arvind  Arvind  Arvind

# %%
print(f"{'=' * r}\n{fullname}\n{'=' * r}")
# Out:
# ...
# Arvind reddy
# ...

# %%
print(f"Length of first name {fname} is : {len(fname)} \nLength of last name {lname} is : {len(lname)}")
# Out:
# Length of first name  Arvind  is : 8
# Length of last name reddy is : 5

# %%
print(f"{fullname[0]}")
# Out:
# A

# %%
print(f"{fullname[:5]}")
# Out:
# Arvin

# %%
print(f"{fullname[6:]}")
# Out:
#  reddy

# %%
print(f"{fullname[0:6:7]}")
# Out:
# A

# %%
print(f"{fullname[0:6:4]}")
# Out:
# An

# %%
print(f"first name  is complete uppercase : {fname.upper()}")
# Out:
# first name  is complete uppercase :  ARVIND

# %%
print(F"Fisrt name is complete LowerCase : {fname.lower()}")
# Out:
# Fisrt name is complete LowerCase :  arvind

# %%
data="data science "
print(f"data  at present : {data}\n Data after striping  : {data.strip()}")
# Out:
# data  at present : data science
#  Data after striping  : data science

# %%
data= "data science "
print(f"data at present : {data} \n data after left striping : {data.strip()}")
# Out:
# data at present : data science
#  data after left striping : data science

# %%
data = "data science "
print(f"data at present : {data} \n data after left striping : {data.lstrip()}")
# Out:
# data at present : data science
#  data after left striping : data science

# %%
data = "data scince "
print(f" data at present {data} \n data after right striping : {data.rstrip()}")
# Out:
#  data at present data scince
#  data after right striping : data scince

# %%
data = "data science=="
print(f"data at present {data} \n data after strinig : {data.strip('=')}")
# Out:
# data at present data science==
#  data after strinig : data science

# %% [markdown]
# Replace

# %%
name =  "arvind"
result = name.replace(" " , " ")
print(result)
# Out:
# arvind

# %%
name  = "arvind"
result = name.replace("arvind" , "reddy")
print(result)
# Out:
# reddy

# %%
name = "arvind is good"
split = name.split(" ")
print(split)
# Out:
# ['arvind', 'is', 'good']

# %%
litr =  ("arvind" , "vilas" , "varun " , "manoj")
join = "-" . join(litr)
print(join)
# Out:
# arvind-vilas-varun -manoj

# %%
name = ("arvind")
swith =name.startswith("vilas")
print(swith)
# Out:
# False

# %%
name = ("arvind")
swith  = name.startswith("arvind")
print(swith)
# Out:
# True

# %% [markdown]
# find & index function
